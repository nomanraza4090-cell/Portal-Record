# %% [markdown]
# # Pandas DataFrame Detective

# %%
import numpy as np
import pandas as pd

dict = pd.DataFrame ({'Name': ['Alice','Bob','Charlie','Diana','Eve','Frank'],
                     'Age': [25,30,np.nan,35,28,np.nan],
                     'Score': [85,92,78,np.nan,88,95],
                     'Grade': ['A','A','B','C','B','A']}) 

df = dict
df
# Out:
#       Name   Age  Score Grade
# 0    Alice  25.0   85.0     A
# 1      Bob  30.0   92.0     A
# 2  Charlie   NaN   78.0     B
# 3    Diana  35.0    NaN     C
# 4      Eve  28.0   88.0     B
# 5    Frank   NaN   95.0     A

# %%
df.head(3)
# Out:
#       Name   Age  Score Grade
# 0    Alice  25.0   85.0     A
# 1      Bob  30.0   92.0     A
# 2  Charlie   NaN   78.0     B

# %%
df.shape
# Out:
# (6, 4)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Score', 'Grade'], dtype='str')

# %%
df.dtypes
# Out:
# Name         str
# Age      float64
# Score    float64
# Grade        str
# dtype: object

# %%
df.isnull().sum()
# Out:
# Name     0
# Age      2
# Score    1
# Grade    0
# dtype: int64

# %%
m = df['Age'].mean()
m
# Out:
# np.float64(29.5)

# %%
df['Age'] = df['Age'].fillna(m)
df['Age']
# Out:
# 0    25.0
# 1    30.0
# 2    29.5
# 3    35.0
# 4    28.0
# 5    29.5
# Name: Age, dtype: float64

# %%
df.dropna()
# Out:
#       Name   Age  Score Grade
# 0    Alice  25.0   85.0     A
# 1      Bob  30.0   92.0     A
# 2  Charlie  29.5   78.0     B
# 4      Eve  28.0   88.0     B
# 5    Frank  29.5   95.0     A

# %%
df[['Name' , 'Score']]
# Out:
#       Name  Score
# 0    Alice   85.0
# 1      Bob   92.0
# 2  Charlie   78.0
# 3    Diana    NaN
# 4      Eve   88.0
# 5    Frank   95.0

# %%
df[df['Score'] > 85]
# Out:
#     Name   Age  Score Grade
# 1    Bob  30.0   92.0     A
# 4    Eve  28.0   88.0     B
# 5  Frank  29.5   95.0     A

# %%
df.set_index('Name')
# Out:
#           Age  Score Grade
# Name
# Alice    25.0   85.0     A
# Bob      30.0   92.0     A
# Charlie  29.5   78.0     B
# Diana    35.0    NaN     C
# Eve      28.0   88.0     B
# Frank    29.5   95.0     A

# %%
df['Grade'].unique()
# Out:
# <StringArray>
# ['A', 'B', 'C']
# Length: 3, dtype: str

# %%
df['Grade'].count()
# Out:
# np.int64(6)

# %%
df.sort_values('Score' , ascending=False)
# Out:
#       Name   Age  Score Grade
# 5    Frank  29.5   95.0     A
# 1      Bob  30.0   92.0     A
# 4      Eve  28.0   88.0     B
# 0    Alice  25.0   85.0     A
# 2  Charlie  29.5   78.0     B
# 3    Diana  35.0    NaN     C

# %%
arr[2:4,3:5]
