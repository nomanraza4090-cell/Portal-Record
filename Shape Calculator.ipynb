# %%
# Objective: Demonstrate Operator Overloading
# Class: Rectangle


class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def __str__(self):
        return f"Rectangle(width={self.width}, height={self.height})"

    def area(self):
        return self.width * self.height

    def __add__(self, other):
        if isinstance(other, Rectangle):
            new_width = self.width + other.width
            new_height = self.height + other.height
            return Rectangle(new_width, new_height)
        return NotImplemented

    def __eq__(self, other):
        if isinstance(other, Rectangle):
            return self.area() == other.area()
        return NotImplemented


rect1 = Rectangle(4, 5)
rect2 = Rectangle(2, 3)

rect4 = Rectangle(1, 6)  

print("Rectangle 1:", rect1)
print("Rectangle 2:", rect2)
print(f"Area of rect1: {rect1.area()}")

rect3 = rect1 + rect2
print(f"rect3 (rect1 + rect2): {rect3}")

# 9. Compare rectangles
print("\nAre rect1 and rect2 equal?")
print(rect1 == rect2)

print("Are rect2 and rect4 equal?")
print(rect2 == rect4)
# Out:
# Rectangle 1: Rectangle(width=4, height=5)
# Rectangle 2: Rectangle(width=2, height=3)
# Area of rect1: 20
# rect3 (rect1 + rect2): Rectangle(width=6, height=8)
#
# Are rect1 and rect2 equal?
# False
# Are rect2 and rect4 equal?
# True
